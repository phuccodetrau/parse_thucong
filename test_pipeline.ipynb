# %%
from preprocess_data.parse_data import ParseHandler
from preprocess_data.chunking import ChunkHandler
import os
import io
api_key = os.environ["OPENAI_API_KEY"]

# %%
def parsing(file_stream, pdf_path):
    parsehandler = ParseHandler.get_instance(api_key=api_key)
    image_base64s = parsehandler.pdf_to_images(file_stream, pdf_path)
    pdf_info, tables = parsehandler.parse_pdf(image_base64s, pdf_path)
    return pdf_info, tables

# %%
def chunking(pdf_info, tables):
    chunkhandler = ChunkHandler.get_instance(api_key)
    chunks = []
    articles = chunkhandler.create_article(pdf_info)
    chunks.extend(articles)

    forms = chunkhandler.create_form(pdf_info)
    chunks.extend(forms)

    tbls = chunkhandler.create_table(tables)
    chunks.extend(tbls)

    equations = chunkhandler.create_equation(pdf_info)
    chunks.extend(equations)

    return chunks

# %%
def pdf_to_stream(file_path):
    with open(file_path, 'rb') as pdf_file:
        pdf_content = pdf_file.read()
        pdf_stream = io.BytesIO(pdf_content)
    return pdf_stream

# %%
file_path = 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf'
pdf_stream = pdf_to_stream(file_path)

# %%
pdf_info, tables = parsing(pdf_stream, file_path)

# %%
pdf_info
# Out:
# {'content': '* Trang 1\n\n# QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG\n\nSửa đổi 1: Ngày 01 tháng 01 năm 2011  \nSửa đổi 2: Ngày 01 tháng 05 năm 2011  \nSửa đổi 3: Ngày 01 tháng 01 năm 2012  \nSửa đổi 4: Ngày 01 tháng 05 năm 2013  \nSửa đổi 5: Ngày 01 tháng 01 năm 2014  \nSửa đổi 6: Ngày 01 tháng 01 năm 2015  \nSửa đổi 7: Ngày 01 tháng 01 năm 2016  \nSửa đổi 8: Ngày 01 tháng 01 năm 2017  \nSửa đổi 9: Ngày 01 tháng 01 năm 2022  \nSửa đổi 10: Ngày 01 tháng 01 năm 2023  \nSửa đổi 11: Ngày 01 tháng 12 năm 2023  \n\n# CÔNG TY TNHH BƠM Ebara VIỆT NAM\n\nPhê duyệt bởi  \nTổng giám đốc  \n\nSoạn thảo bởi  \nBan Nhân sự  \n\nTetsuya Fuchida  \nNguyen Tu Khanh  \n\n* Trang 2\n\n# Điều 1: Quy định về tiền lương\nCông ty sẽ trả lương cho toàn bộ công nhân viên theo lương tháng và lương ngày, coi đó là sự bù đắp sức lao động trên cơ sở xem xét kết quả trình làm việc, thành tích, năng suất, chất lượng, hiệu quả công việc và sinh hoạt phí phù hợp với tình hình xã hội và kết quả kinh doanh của công ty.\n\n# Điều 2: Cơ cấu tiền lương\n## Lương thường xuyên\n(Theo Phụ lục I)\n\n- Lương cấp bậc\n  - (*) Trong lương cấp bậc đã bao gồm Phụ cấp chức vụ, Phụ cấp đặc biệt, Phụ cấp chức ngành, Phụ cấp độc hại.\n  - Trợ cấp liên quan đời sống\n  - Trợ cấp nhà ở\n  - Trợ cấp đi lại\n  - Lunch Support\n  - Trợ cấp ăn trưa\n  - Trợ cấp khác (nếu có)\n\n## Lương không thường xuyên\n- Phụ cấp làm thêm giờ ngày thường\n- Phụ cấp làm thêm giờ ngày nghỉ\n- Phụ cấp làm đêm\n\n# Điều 3: Lương thường xuyên\n(*) Thể hiện tại Phụ lục I, trong đó:\n+ Ngạch lương thể hiện vị trí, chức năng, nghiệp vụ của nhân viên.\n+ Bậc lương thể hiện thứ bậc được sắp xếp theo thứ tự ở mỗi ngạch lương.\n+ Mức lương thể hiện giá trị trọng mỗi bậc lương (từ tối thiểu đến tối đa).\n\n* Trang 3\n\n# Lương thưởng xuyên\n\n(*) Lương thưởng xuyên bao gồm 2 yếu tố dưới đây:  \nLương thưởng xuyên = Lương cấp bậc + Phụ cấp đời sống\n\n1- Công ty xây dựng Bảng lương thưởng xuyên trên cơ sở xem xét mức lương tối thiểu theo quy định của pháp luật và/h hoặc chỉ số giá tiêu dùng được ban hành bởi Chính phủ cũng như Báo cáo khảo sát tiền lương trên thị trường lao động Việt Nam (dữ liệu tham khảo hiện nay là Khảo sát lương 2023 dành cho khối sản xuất có vốn đầu tư Nhật Bản do tập đoàn Navigos công bố).\n\n2- Ít nhất 1 lần trong 5 năm, Bảng lương thưởng xuyên sẽ được chỉnh sửa nếu thấy kết quả khảo sát lương trên thị trường lao động có sự thay đổi đáng kể hoặc chỉ số giá tiêu dùng biến động từ 15% trở lên.\n\n3- Bảng Lương thưởng xuyên được phân thành 5 nhóm theo phạm vi công việc của từng nhân viên như sau:\n\n1) Nhóm 1 / Nhóm Quản lý (M): Cấp Trưởng Phòng, Trưởng Ban, Giám đốc nhà máy.  \n2) Nhóm 2 / Nhóm Chuyên viên (P): Tổ trưởng, Nhóm trưởng và những nhân viên có kỹ năng nghề nghiệp cao, được xét chọn bởi Nhóm Quản lý.  \n3) Nhóm 3 (E)/ Kỹ sư, chuyên gia, người có kinh nghiệm.  \n4) Nhóm 4 (G)/ Nhân viên nghiệp vụ: làm công việc hỗ trợ dịch vụ, hành chính tại các bộ phận.  \n5) Nhóm 5 (S)/ Công nhân kỹ thuật: làm việc trực tiếp tại xưởng sản xuất hoặc công trường.  \n\n## I. Lương cấp bậc bao gồm: Phụ cấp chức vụ, Phụ cấp đặc biệt, Phụ cấp kỹ năng nghề, Phụ cấp năng nhọc độc hại nguy hiểm, trong đó lưu ý:\n\na) Phụ cấp kỹ năng nghề  \nNgười lao động có chứng chỉ kỹ năng nghề nghiệp do JAVADA (Hiệp hội phát triển năng lực nghề nghiệp Nhật Bản) quy định hoặc tương đương sẽ được trả cấp kỹ năng nghề nghiệp hàng tháng. “Phụ cấp kỹ năng nghề” này được quy định tại Phụ lục II.\n\nb) Phụ cấp công việc năng nhọc, độc hại nguy hiểm  \nNgười lao động làm công việc năng nhọc, độc hại, nguy hiểm như liệt kê tại Phụ lục III: EVPC - Danh mục nghề, công việc năng nhọc, độc hại và đặc biệt năng nhọc, độc hại, sẽ được áp dụng Phụ cấp lao động năng nhọc là 500.000 đồng:\n\n- Nhóm Nấu luyện, nhóm Hoàn thiện và nhóm Khuôn đúc thuộc phòng Đức, ban Sản xuất & Vật liệu  \n- Nhóm Gò hàn rèn, phòng Gò hàn rèn, ban Sản xuất & Vật liệu  \n\n* Trang 4\n\n# Thông tin quản lý\n## II. Phụ cấp đời sống\n### 1. Phụ cấp nhà ở\nCông ...
#  'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG ',
#  'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf'}

# %%
tables
# Out:
# [{'page': 5,
#   'content': 'Table 1\n\n| Khấu trừ 1 ngày vắng mặt | = | Lương thường xuyên  | *  | (1 - Số ngày làm việc tiêu chuẩn hàng tháng (= 22*)) |\n\nTable 2\n\n| Lương tháng trong thời gian thử việc | = | [Lương thường xuyên * 85%] | * | (1 - Số ngày làm việc tiêu chuẩn hàng tháng (22 ngày) * \nSố ngày làm việc trong tháng)  |\n',
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG ',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf'},
#  {'page': 6,
#   'content': 'Table 1\n\n|                   | Ngày thường | Thứ 7, Chủ nhật & Ngày nghỉ Lễ của Công ty | Ngày lễ  |\n|-------------------|--------------|--------------------------------------------|----------|\n| 6:00AM - 22:00    | 1.5          | 2.0                                        | 3.0      |\n| 22:00 - 6:00AM    | 2.1 = 1.5 + 0.3**3 + (0.2**3 x 1.5) | 2.7 = 2.0 + 0.3**3 + (0.2**3 x 2.0)          | 3.9 = 3.0 + 0.3**3 + (0.2**3 x 3.0) |',
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG ',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf'},
#  {'page': 7,
#   'content': 'Table 1\n\n| Xếp loại đánh giá | Loại | Ghi chú                          |\n|-------------------|------|-----------------------------------|\n| Xuất sắc          | A    | Thể hiện năng lực xuất sắc       |\n| Tốt               | B+/B | Thể hiện năng lực cao hơn mức yêu cầu |\n| Trung bình        | C    | Thể hiện năng lực đạt mức yêu cầu |\n| Kém               | D    | Thể hiện năng lực thấp hơn mức yêu cầu |',
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG ',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf'},
#  {'page': 8,
#   'content': 'Table 1\n\n| Bậc lương chuyển đổi | Đối tượng được xét chuyển đổi                                                           | Tiêu chuẩn được xét chuyển đổi                                                                 |\n|---------------------|-------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------|\n|                     |                                                                                     | Người đánh giá                          | Kinh nghiệm làm việc liên quan đến bậc lương được chuyển đổi | Xếp loại để được chuyển bậc                       |\n| Ngạch P             | Nhóm 2 Tổ Trưởng, Nhóm Trưởng, Chuyên viên                                          | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch E             | Nhóm 3 Kỹ sư, cử nhân người có KH                                                   | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch G             | Nhóm 3 Nhân viên nghiệp vụ                                                          | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch S             | Nhóm 4 Công nhân kỹ thuật                                                           | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch M             | Nhóm 1/ Quản lý                                                                     | Tổng Giám Đốc trực tiếp đánh giá cùng các Trưởng Ban thông qua phòng vấn trực tiếp |                                                    |        |',
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG ',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf'},
#  {'page': 9,
#   'content': 'Table 1\n\nThanh toán một ngày phép tồn = Lương cấp bậc / Số ngày làm việc tiêu chuẩn hàng tháng (= 22)',
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG ',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf'},
#  {'page': 10,
#   'content': 'Table 1:\n\nNumber of years working at EVPC | Bonus amount (VND)\n--------------------------------|--------------------\n5 years                         | 1.500.000\n10 years                        | 3.000.000\n15 years                        | 4.500.000\n20 years                        | 6.000.000\n25 years                        | 7.500.000\n30 years                        | 9.000.000\n35 năm                          | 10.500.000\n40 năm                          | 12.000.000',
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG ',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf'}]

# %%
print(pdf_info["content"])
# Out:
# * Trang 1
#
# # QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG
#
# Sửa đổi 1: Ngày 01 tháng 01 năm 2011
# Sửa đổi 2: Ngày 01 tháng 05 năm 2011
# Sửa đổi 3: Ngày 01 tháng 01 năm 2012
# Sửa đổi 4: Ngày 01 tháng 05 năm 2013
# Sửa đổi 5: Ngày 01 tháng 01 năm 2014
# Sửa đổi 6: Ngày 01 tháng 01 năm 2015
# Sửa đổi 7: Ngày 01 tháng 01 năm 2016
# Sửa đổi 8: Ngày 01 tháng 01 năm 2017
# Sửa đổi 9: Ngày 01 tháng 01 năm 2022
# Sửa đổi 10: Ngày 01 tháng 01 năm 2023
# Sửa đổi 11: Ngày 01 tháng 12 năm 2023
#
# # CÔNG TY TNHH BƠM Ebara VIỆT NAM
#
# Phê duyệt bởi
# Tổng giám đốc
#
# Soạn thảo bởi
# Ban Nhân sự
#
# Tetsuya Fuchida
# Nguyen Tu Khanh
#
# * Trang 2
#
# # Điều 1: Quy định về tiền lương
# Công ty sẽ trả lương cho toàn bộ công nhân viên theo lương tháng và lương ngày, coi đó là sự bù đắp sức lao động trên cơ sở xem xét kết quả trình làm việc, thành tích, năng suất, chất lượng, hiệu quả công việc và sinh hoạt phí phù hợp với tình hình xã hội và kết quả kinh doanh của công ty.
#
# # Điều 2: Cơ cấu tiền lương
# ## Lương thường xuyên
# (Theo Phụ lục I)
#
# - Lương cấp bậc
#   - (*) Trong lương cấp bậc đã bao gồm Phụ cấp chức vụ, Phụ cấp đặc biệt, Phụ cấp chức ngành, Phụ cấp độc hại.
#   - Trợ cấp liên quan đời sống
#   - Trợ cấp nhà ở
#   - Trợ cấp đi lại
#   - Lunch Support
#   - Trợ cấp ăn trưa
#   - Trợ cấp khác (nếu có)
#
# ## Lương không thường xuyên
# - Phụ cấp làm thêm giờ ngày thường
# - Phụ cấp làm thêm giờ ngày nghỉ
# - Phụ cấp làm đêm
#
# # Điều 3: Lương thường xuyên
# (*) Thể hiện tại Phụ lục I, trong đó:
# + Ngạch lương thể hiện vị trí, chức năng, nghiệp vụ của nhân viên.
# + Bậc lương thể hiện thứ bậc được sắp xếp theo thứ tự ở mỗi ngạch lương.
# + Mức lương thể hiện giá trị trọng mỗi bậc lương (từ tối thiểu đến tối đa).
#
# * Trang 3
#
# # Lương thưởng xuyên
#
# (*) Lương thưởng xuyên bao gồm 2 yếu tố dưới đây:
# Lương thưởng xuyên = Lương cấp bậc + Phụ cấp đời sống
#
# 1- Công ty xây dựng Bảng lương thưởng xuyên trên cơ sở xem xét mức lương tối thiểu theo quy định của pháp luật và/h hoặc chỉ số giá tiêu dùng được ban hành bởi Chính phủ cũng như Báo cáo khảo sát tiền lương trên thị trường lao động Việt Nam (dữ liệu tham khảo hiện nay là Khảo sát lương 2023 dành cho khối sản xuất có vốn đầu tư Nhật Bản do tập đoàn Navigos công bố).
#
# 2- Ít nhất 1 lần trong 5 năm, Bảng lương thưởng xuyên sẽ được chỉnh sửa nếu thấy kết quả khảo sát lương trên thị trường lao động có sự thay đổi đáng kể hoặc chỉ số giá tiêu dùng biến động từ 15% trở lên.
#
# 3- Bảng Lương thưởng xuyên được phân thành 5 nhóm theo phạm vi công việc của từng nhân viên như sau:
#
# 1) Nhóm 1 / Nhóm Quản lý (M): Cấp Trưởng Phòng, Trưởng Ban, Giám đốc nhà máy.
# 2) Nhóm 2 / Nhóm Chuyên viên (P): Tổ trưởng, Nhóm trưởng và những nhân viên có kỹ năng nghề nghiệp cao, được xét chọn bởi Nhóm Quản lý.
# 3) Nhóm 3 (E)/ Kỹ sư, chuyên gia, người có kinh nghiệm.
# 4) Nhóm 4 (G)/ Nhân viên nghiệp vụ: làm công việc hỗ trợ dịch vụ, hành chính tại các bộ phận.
# 5) Nhóm 5 (S)/ Công nhân kỹ thuật: làm việc trực tiếp tại xưởng sản xuất hoặc công trường.
#
# ## I. Lương cấp bậc bao gồm: Phụ cấp chức vụ, Phụ cấp đặc biệt, Phụ cấp kỹ năng nghề, Phụ cấp năng nhọc độc hại nguy hiểm, trong đó lưu ý:
#
# a) Phụ cấp kỹ năng nghề
# Người lao động có chứng chỉ kỹ năng nghề nghiệp do JAVADA (Hiệp hội phát triển năng lực nghề nghiệp Nhật Bản) quy định hoặc tương đương sẽ được trả cấp kỹ năng nghề nghiệp hàng tháng. “Phụ cấp kỹ năng nghề” này được quy định tại Phụ lục II.
#
# b) Phụ cấp công việc năng nhọc, độc hại nguy hiểm
# Người lao động làm công việc năng nhọc, độc hại, nguy hiểm như liệt kê tại Phụ lục III: EVPC - Danh mục nghề, công việc năng nhọc, độc hại và đặc biệt năng nhọc, độc hại, sẽ được áp dụng Phụ cấp lao động năng nhọc là 500.000 đồng:
#
# - Nhóm Nấu luyện, nhóm Hoàn thiện và nhóm Khuôn đúc thuộc phòng Đức, ban Sản xuất & Vật liệu
# - Nhóm Gò hàn rèn, phòng Gò hàn rèn, ban Sản xuất & Vật liệu
#
# * Trang 4
#
# # Thông tin quản lý
# ## II. Phụ cấp đời sống
# ### 1. Phụ cấp nhà ở
# Công ty dự phòng chi trả Phụ cấp nhà ở 500,000 đồng cho nhân viên sống tại tỉnh Hải Dương và các tỉnh khác (trừ Hà Nội, Hồ Chí Minh và Đồng Nai) và 1,000,000 đồng cho nhân viên cư trú tại Thành phố Hà Nội, Thành phố Hồ Chí Minh và tỉnh Đồng Nai.
#
# ### 2. Phụ cấp di lại
# Công ty hỗ trợ phụ cấp di lại cho toàn thể nhân viên 500,000đ.
#
# ### 3. Phụ cấp hỗ trợ ăn trưa
# Nhân viên làm việc tại Văn phòng đại diện Hà Nội, Chi nhánh Đồng Nai được hỗ trợ ăn trưa 800,000đ. Nhân viên làm việc tại Trụ sở chính và Nhà máy được cung cấp bữa trưa miễn phí tại công ty.
#
# ### 4. Phụ cấp khác
# - Người lao động được hưởng bảo hiểm xã hội (đã nghỉ hưu nhưng vẫn tiếp tục làm việc tại công ty) được hưởng Trợ cấp Bảo hiểm xã hội theo quy định của Luật Lao động. Phụ cấp Bảo hiểm xã hội được tính dựa trên tổng số lương theo Lương cấp bậc.
# - Đối với nhân viên được chỉ định thường xuyên di chuyển đến làm việc tại chi nhánh, nhà máy sẽ được hưởng Phụ cấp di lại (tối đa 2 triệu/tháng). Mức phụ cấp này do Tổng Giám đốc quyết định tùy theo từng trường hợp.
#
# #### Điều 4. Kỳ tính lương
# Kỳ tính lương được xác định như sau:
# 1. Lương thường xuyên: Từ ngày 1 đến cuối tháng hiện tại
# 2. Lương không thường xuyên: Từ ngày 1 đến cuối tháng hiện tại
#
# #### Điều 5. Phương thức trả lương
# Công ty trả lương bằng tiền mặt hoặc chuyển khoản vào tài khoản ngân hàng của người lao động.
#
# #### Điều 6. Ngày trả lương
# Tiền lương phải được mô tả chi tiết vào trước ngày trả lương và công ty thực hiện chỉ trả cho người lao động vào ngày 10 của tháng tiếp theo. Người lao động có thể bị khấu trừ lương trong các trường hợp.
#
# * Trang 5
#
# # Confidential
#
# 1)
# a. Thuế thu nhập cá nhân
# b. Bảo hiểm xã hội, bảo hiểm y tế, bảo hiểm thất nghiệp
# c. Các khoản trừ trước
# d. Bồi thường
# e. Các chi phí khác do Công ty và Công đoàn thoả thuận.
#
# 2) Trường hợp ngày thanh toán lương là ngày nghỉ lễ thì việc trả lương được thực hiện vào ngày làm việc trước đó.
#
# 3) Tiền lương được ưu tiên thanh toán trước các chi phí khác.
#
# 4) Việc đóng Bảo hiểm xã hội được tính căn cứ vào tiền lương Cấp bậc (không tính phụ cấp liên quan đến đời sống).
#
# 5) Việc thay đổi ngày trả lương do trưởng hợp kháng phải thông báo cho người lao động trước 7 ngày. Công ty có trách nhiệm trả lãi cho người lao động theo quy định của ngân hàng nếu chậm trả lương từ 15 ngày trở lên.
#
# 6) Khấu trừ lương
# Trường hợp vắng mặt (do nghỉ không lương, nghỉ hưởng chế độ Bảo hiểm xã hội, …), công ty sẽ khấu trừ vào lương của người lao động theo công thức sau:
# $$ Khấu trừ 1 ngày vắng mặt = Lương thưởng xuyên $$
# $$ = \text{Số ngày làm việc tiêu chuẩn hàng tháng} (= 22*) $$
#
# ## Điều 7. Trả lương trong thời gian thử việc
# Trong thời gian thử việc, tiền lương được tính theo công thức sau:
# $$ Lương tháng trong thời gian thử việc = [\text{Lương thưởng xuyên} * 85\% ] $$
# $$ = \text{Ngày làm việc tiêu chuẩn hàng tháng (22 ngày)} $$
#
# ## Điều 8. Thanh toán đặc biệt
# Khi xem xét yêu cầu thuộc các trường hợp sau đây, Công ty phải trả lương cho người lao động theo phần công việc hoa nhân và không phụ thuộc vào Điều 6 - Ngày trả lương:
# 1) Nhân viên/cán bộ chết.
# 2) Chấm dứt hợp đồng lao động.
# 3) Nhân viên/Cán bộ hoặc gia đình họ cần tiền để chi trả cho tai nạn, thương tích, bệnh tật hoặc thiên tai.
# 4) Nhân viên/Cán bộ hoặc gia đình họ cần tiền để chi trả cho đám cưới, sinh con, tang lễ.
#
# * Trang 6
#
# # 5) Các trường hợp sự chấp thuận của Công ty.
#
# #### Điều 9. Tạm ứng tiền lương
# Trong khi xem xét yêu cầu hoặc các trường hợp sau đây, Công ty sẽ tạm ứng trước cho người lao động. Tuy nhiên, nó phải đảm bảo tuân thủ các quy định khác.
# 1) Nhân viên/Cán bộ hoặc gia đình họ cần tiền để chi trả cho những khó khăn phát sinh.
# 2) Nhân viên/Cán bộ nghỉ để tham gia các hoạt động theo yêu cầu của Chính quyền.
# 3) Các trường hợp có sự chấp thuận của Công ty.
#
# #### Điều 10. Lương không thường xuyên
# Phụ cấp này được tính theo công thức sau:
# Phụ cấp làm thêm ngoài giờ (mỗi 1 giờ)
# $$
# = (Lương cấp bậc) * Hệ số phụ cấp * 1
# $$
# $$
# = (Lương cấp bậc) * Hệ số phụ cấp * 1
# $$
# $$
# = 22 (ngày) * 8 (giờ)
# $$
#
# *1) Hệ số phụ cấp được tính như sau:
# Ngày thường | Thứ 7, Chủ nhật & Ngày nghỉ lễ của Công ty | Ngày lễ
# ---|---|---
# 6:00AM - 22:00 | 1.5 | 2.0 | 3.0
# 22:00 - 6:00AM | 2.1 | 2.7 | 3.9
# $$
# = 1.5 + 0.3*2 + (0.2) \times 1.5
# $$
# $$
# = 2.0 + 0.3*2 + (0.2) \times 2.0
# $$
# $$
# = 3.0 + 0.3*2 + (0.2) \times 3.0
# $$
#
# *2) Hệ số phụ cấp làm việc ca đêm
# *3) Hệ số phụ cấp làm thêm giờ vào ban đêm
#
# Phụ cấp làm việc ca đêm
# Người lao động làm việc ca đêm (từ 22h đến 6h) được hưởng thêm các khoản phụ cấp sau:
# Phụ cấp làm việc ca ban đêm (mỗi 1 giờ)
# $$
# = (Lương cấp bậc) * 0.3
# $$
# $$
# = (Lương cấp bậc) * 0.3
# $$
# $$
# = 22 (ngày) * 8 (giờ)
# $$
#
# (*) Làm thêm giờ chỉ áp dụng đối với các công việc trực tiếp tại nhà máy, văn phòng, công trường dự án. Thời gian tiếp khách hoặc di chuyển trên đường sẽ không được tính là làm thêm giờ.
#
# * Trang 7
#
# # Điều 11. Lương ngừng việc
# Căn cứ Điều 99 Bộ luật Lao động 2019, trường hợp tạm ngừng việc thì tiền lương ngừng việc được trả như sau:
#
# 1) Nếu do lỗi từ phía Công ty, người lao động được thanh toán lương theo Bảng lương.
#
# 2) Nếu do lỗi từ phía người lao động thì người lao động đươc không được trả lương.
#
# 3) Trường hợp vì sự cố diện, nước không phải do lỗi của Công ty hoặc do thiên tai, hoả hoạn, dịch bệnh, dịch hoạ, di dời theo yêu cầu của cơ quan có thẩm quyền hoặc vì do kinh tế, hai bên sẽ thoả thuận mức lương như sau:
#
# a) Nếu thời gian ngừng việc không quá 14 ngày làm việc; tùy trường hợp công ty sẽ bố trí làm việc trả lương vào ngày khác hoặc bố trí nghỉ phép hằng năm hoặc công ty trả 75% lương theo Bảng lương.
#
# b) Nếu ngừng việc quá 14 ngày làm việc thì mức lương do hai bên thoả thuận (nhưng không thấp hơn mức lương tối thiểu vùng I hiện hành của Chính phủ).
#
# # Điều 12. Đánh giá, xác định tiền lương và quy chế tăng/ giảm lương
# 1) Định kỳ hàng tháng/ quý hoặc năm, Công ty có thể xem xét và xác định mức lương của nhân viên dựa trên khả năng, trình độ, điều kiện làm việc, vai trò, kết quả đánh giá hiệu quả công việc, sự tuân thủ nội quy quy định, tiến trình chuyên cần. Các trường hợp đặc biệt Công ty có thể thay đổi mức lương khi thấy cần thiết căn cứ vào hiệu quả công việc thực tế của từng trường hợp cụ thể.
#
# 2) Tăng tiền lương và tiêu chuẩn xác định mức lương được xác định theo trường hợp cụ thể căn cứ theo kết quả đánh giá hiệu quả công việc của nhân viên và phân loại đánh giá theo phương pháp đánh giá như sau:
#
# Xếp loại đánh giá | Loại | Ghi chú
# --- | --- | ---
# Xuất sắc | A | Thể hiện năng lực xuất sắc
# Tốt | B+/B | Thể hiện năng lực cao hơn mức yêu cầu
# Trung bình | C | Thể hiện năng lực đạt mức yêu cầu
# Kém | D | Thể hiện năng lực thấp hơn mức yêu cầu
#
# * Trang 8
#
# # Điều 13. Điều kiện chuyển đổi Ngạch lương/Bậc lương
#
# 1- Việc chuyển đổi Ngạch lương chỉ áp dụng khi người lao động được giao một công việc hoặc chức vụ mới.
#
# 2- Việc chuyển đổi bậc lương trong mỗi ngạch lương sẽ áp dụng như sau:
#
# ## Bậc lương chuyển đổi
#
# ### Đối tượng được xét chuyển đổi
#
# | Ngạch P    | Nhóm 2 Tổ trưởng, Nhân viên, Chuyên viên                           | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B* > B > C > D |
# |------------|---------------------------------------------------------------------|---------------------------------------------|----------|--------------------|
# | Ngạch E    | Nhóm 3 Kỹ sư, cử nhân người có KN                                   | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B* > B > C > D |
# | Ngạch G    | Nhóm 3 Nhân viên nghiệp vụ                                         | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B* > B > C > D |
# | Ngạch S    | Nhóm 4 Công nhân kỹ thuật                                          | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B* > B > C > D |
# | Ngạch M    | Nhóm 1/Quản lý                                                     | Tổng Giám Đốc trực tiếp đánh giá các Trưởng Ban thông qua phòng vận trực tiếp |          |                    |
#
# * Trang 9
#
# # Quy chế xét tăng/giảm lương:
# - Người lao động được đánh giá loại A sẽ được tăng 100% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.
# - Người lao động được đánh giá loại B sẽ được tăng 80% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.
# - Người lao động được đánh giá loại C sẽ được tăng 70% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.
# - Người lao động được đánh giá loại D sẽ chỉ được 50% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.
# - (*) Trường hợp đặc biệt khi NLD bị đánh giá loại D 3 năm liên tiếp thì xem xét chấm đứt HĐLĐ.
# - Trường hợp đặc biệt khác cần đưa ra điều kiện tăng bậc lương, tùy nhiên cần được cán bộ nhân sự chấp thuận trước ủy Ban Giám Đốc.
#
# #### Điều 14. Tiền lương nghỉ phép hàng năm và ngày nghỉ đặc biệt được hưởng nguyên lương
# - Công ty sẽ thanh toán những phép tôn đối với người lao động do thời viện hoặc mất việc làm.
#   + Ngày nghỉ phép hàng năm chưa dùng sẽ được tính theo công thức sau:
#
# $$
# \text{Lương cấp bậc} = \frac{\text{Số ngày làm việc tiêu chuẩn hàng tháng (= 22)}}{\text{Thanh toán một ngày phép tôn}}
# $$
#
# #### Điều 15. Trả lương cho gia đình người lao động qua đời
# Giải quyết việc thanh toán tiền lương cho thân nhân người lao động qua đời được thực hiện theo quy định của pháp luật Việt Nam.
#
# #### Điều 16. Tiền thưởng cuối năm
# 1) Công ty thực hiện việc thanh toán thưởng mỗi năm một lần khi hoạt động kinh doanh có lãi.
# 2) Tiền thưởng được căn cứ vào tiền lương Cấp bậc và Kết quả đóng góp của người lao động trong năm đó dựa vào Bảng đánh giá cuối năm (MBO hoặc trung đường).
# 3) Nếu hoạt động kinh doanh của Công ty không có lãi thì tiền thưởng sẽ không có hoặc việc thanh toán Tiền thưởng sẽ bị hoãn.
# 4) Người lao động nghỉ việc trước ngày 31 tháng 12 hàng năm không được thưởng. Tuy nhiên nếu Người lao động nghỉ hưu vào thời điểm trước 31/12 hàng năm thì sẽ được xem thưởng dựa trên số tháng còn làm việc tại công ty trong năm cuối cùng đó. Việc trả thưởng sẽ tiến hành vào thời điểm cuối năm mà NLD đã nghỉ hưu sẽ chịu thuế TNCN theo luật định tại thời điểm nhận thưởng.
# 5) Trường hợp thưởng đặc biệt khác cần được quy định của Tổng Giám đốc.
# 6) Tiền thưởng phải được tính như sau:
#
# Tổng tiền thưởng = Tiền thưởng x Tỷ lệ làm việc trong năm
#
# * Trang 10
#
# #### Điều 17. Tiền thưởng thâm niên
# Công ty thực hiện việc thưởng thâm niên vào cuối mỗi năm dựa theo các mốc sau:
#
# | Number of years working at EVPC | Bonus amount (VND) |
# |----------------------------------|---------------------|
# | 5 years                          | 1.500.000           |
# | 10 years                         | 3.000.000           |
# | 15 years                         | 4.500.000           |
# | 20 years                         | 6.000.000           |
# | 25 years                         | 7.500.000           |
# | 30 years                         | 9.000.000           |
# | 35 years                         | 10.500.000          |
# | 40 years                         | 12.000.000          |
#
# $$ \text{Tiền thưởng} = \text{Ngày vắng mặt trong năm} \times \left(100 - \frac{\text{Ngày vắng mặt trong năm}}{22 \times 12}\right) $$

# %%
import json
with open("preprocess_data/test_result.json", "w", encoding="utf-8") as json_file:
    json.dump({"pdf_info": pdf_info, "tables": tables}, json_file, indent=4, ensure_ascii=False)

# %%
import json
with open("preprocess_data/test_result.json", "r", encoding="utf-8") as json_file:
    data = json.load(json_file)

# %%
pdf_info = data["pdf_info"]
tables = data["tables"]

# %%
pdf_info
# Out:
# {'content': '* Trang 1\n\n# QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG\n\nSửa đổi 1: Ngày 01 tháng 01 năm 2011  \nSửa đổi 2: Ngày 01 tháng 05 năm 2011  \nSửa đổi 3: Ngày 01 tháng 01 năm 2012  \nSửa đổi 4: Ngày 01 tháng 05 năm 2013  \nSửa đổi 5: Ngày 01 tháng 01 năm 2014  \nSửa đổi 6: Ngày 01 tháng 01 năm 2015  \nSửa đổi 7: Ngày 01 tháng 01 năm 2016  \nSửa đổi 8: Ngày 01 tháng 01 năm 2017  \nSửa đổi 9: Ngày 01 tháng 01 năm 2022  \nSửa đổi 10: Ngày 01 tháng 01 năm 2023  \nSửa đổi 11: Ngày 01 tháng 12 năm 2023  \n\n# CÔNG TY TNHH BƠM Ebara VIỆT NAM\n\nPhê duyệt bởi  \nTổng giám đốc  \n\nSoạn thảo bởi  \nBan Nhân sự  \n\nTetsuya Fuchida  \nNguyen Tu Khanh  \n\n* Trang 2\n\n# Điều 1: Quy định về tiền lương\nCông ty sẽ trả lương cho toàn bộ công nhân viên theo lương tháng và lương ngày, coi đó là sự bù đắp sức lao động trên cơ sở xem xét kết quả trình làm việc, thành tích, năng suất, chất lượng, hiệu quả công việc và sinh hoạt phí phù hợp với tình hình xã hội và kết quả kinh doanh của công ty.\n\n# Điều 2: Cơ cấu tiền lương\n## Lương thường xuyên\n(Theo Phụ lục I)\n\n- Lương cấp bậc\n  - (*) Trong lương cấp bậc đã bao gồm Phụ cấp chức vụ, Phụ cấp đặc biệt, Phụ cấp chức ngành, Phụ cấp độc hại.\n  - Trợ cấp liên quan đời sống\n  - Trợ cấp nhà ở\n  - Trợ cấp đi lại\n  - Lunch Support\n  - Trợ cấp ăn trưa\n  - Trợ cấp khác (nếu có)\n\n## Lương không thường xuyên\n- Phụ cấp làm thêm giờ ngày thường\n- Phụ cấp làm thêm giờ ngày nghỉ\n- Phụ cấp làm đêm\n\n# Điều 3: Lương thường xuyên\n(*) Thể hiện tại Phụ lục I, trong đó:\n+ Ngạch lương thể hiện vị trí, chức năng, nghiệp vụ của nhân viên.\n+ Bậc lương thể hiện thứ bậc được sắp xếp theo thứ tự ở mỗi ngạch lương.\n+ Mức lương thể hiện giá trị trọng mỗi bậc lương (từ tối thiểu đến tối đa).\n\n* Trang 3\n\n# Lương thưởng xuyên\n\n(*) Lương thưởng xuyên bao gồm 2 yếu tố dưới đây:  \nLương thưởng xuyên = Lương cấp bậc + Phụ cấp đời sống\n\n1- Công ty xây dựng Bảng lương thưởng xuyên trên cơ sở xem xét mức lương tối thiểu theo quy định của pháp luật và/h hoặc chỉ số giá tiêu dùng được ban hành bởi Chính phủ cũng như Báo cáo khảo sát tiền lương trên thị trường lao động Việt Nam (dữ liệu tham khảo hiện nay là Khảo sát lương 2023 dành cho khối sản xuất có vốn đầu tư Nhật Bản do tập đoàn Navigos công bố).\n\n2- Ít nhất 1 lần trong 5 năm, Bảng lương thưởng xuyên sẽ được chỉnh sửa nếu thấy kết quả khảo sát lương trên thị trường lao động có sự thay đổi đáng kể hoặc chỉ số giá tiêu dùng biến động từ 15% trở lên.\n\n3- Bảng Lương thưởng xuyên được phân thành 5 nhóm theo phạm vi công việc của từng nhân viên như sau:\n\n1) Nhóm 1 / Nhóm Quản lý (M): Cấp Trưởng Phòng, Trưởng Ban, Giám đốc nhà máy.  \n2) Nhóm 2 / Nhóm Chuyên viên (P): Tổ trưởng, Nhóm trưởng và những nhân viên có kỹ năng nghề nghiệp cao, được xét chọn bởi Nhóm Quản lý.  \n3) Nhóm 3 (E)/ Kỹ sư, chuyên gia, người có kinh nghiệm.  \n4) Nhóm 4 (G)/ Nhân viên nghiệp vụ: làm công việc hỗ trợ dịch vụ, hành chính tại các bộ phận.  \n5) Nhóm 5 (S)/ Công nhân kỹ thuật: làm việc trực tiếp tại xưởng sản xuất hoặc công trường.  \n\n## I. Lương cấp bậc bao gồm: Phụ cấp chức vụ, Phụ cấp đặc biệt, Phụ cấp kỹ năng nghề, Phụ cấp năng nhọc độc hại nguy hiểm, trong đó lưu ý:\n\na) Phụ cấp kỹ năng nghề  \nNgười lao động có chứng chỉ kỹ năng nghề nghiệp do JAVADA (Hiệp hội phát triển năng lực nghề nghiệp Nhật Bản) quy định hoặc tương đương sẽ được trả cấp kỹ năng nghề nghiệp hàng tháng. “Phụ cấp kỹ năng nghề” này được quy định tại Phụ lục II.\n\nb) Phụ cấp công việc năng nhọc, độc hại nguy hiểm  \nNgười lao động làm công việc năng nhọc, độc hại, nguy hiểm như liệt kê tại Phụ lục III: EVPC - Danh mục nghề, công việc năng nhọc, độc hại và đặc biệt năng nhọc, độc hại, sẽ được áp dụng Phụ cấp lao động năng nhọc là 500.000 đồng:\n\n- Nhóm Nấu luyện, nhóm Hoàn thiện và nhóm Khuôn đúc thuộc phòng Đức, ban Sản xuất & Vật liệu  \n- Nhóm Gò hàn rèn, phòng Gò hàn rèn, ban Sản xuất & Vật liệu  \n\n* Trang 4\n\n# Thông tin quản lý\n## II. Phụ cấp đời sống\n### 1. Phụ cấp nhà ở\nCông ...
#  'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG ',
#  'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf'}

# %%
chunks = chunking(pdf_info, tables)

# %%
chunks
# Out:
# [{'raw_text': '# Điều 1: Quy định về tiền lương\nCông ty sẽ trả lương cho toàn bộ công nhân viên theo lương tháng và lương ngày, coi đó là sự bù đắp sức lao động trên cơ sở xem xét kết quả trình làm việc, thành tích, năng suất, chất lượng, hiệu quả công việc và sinh hoạt phí phù hợp với tình hình xã hội và kết quả kinh doanh của công ty.',
#   'content': ' Điều 1: Quy định về tiền lương\nCông ty sẽ trả lương cho toàn bộ công nhân viên theo lương tháng và lương ngày, coi đó là sự bù đắp sức lao động trên cơ sở xem xét kết quả trình làm việc, thành tích, năng suất, chất lượng, hiệu quả công việc và sinh hoạt phí phù hợp với tình hình xã hội và kết quả kinh doanh của công ty.',
#   'summary': 'Đoạn văn bản này chứa thông tin về quy định và chính sách tiền lương của công ty đối với công nhân viên.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 2,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '# Điều 2: Cơ cấu tiền lương\n## Lương thường xuyên\n(Theo Phụ lục I)\n- Lương cấp bậc\n  - (*) Trong lương cấp bậc đã bao gồm Phụ cấp chức vụ, Phụ cấp đặc biệt, Phụ cấp chức ngành, Phụ cấp độc hại.\n  - Trợ cấp liên quan đời sống\n  - Trợ cấp nhà ở\n  - Trợ cấp đi lại\n  - Lunch Support\n  - Trợ cấp ăn trưa\n  - Trợ cấp khác (nếu có)\n## Lương không thường xuyên\n- Phụ cấp làm thêm giờ ngày thường\n- Phụ cấp làm thêm giờ ngày nghỉ\n- Phụ cấp làm đêm',
#   'content': ' Điều 2: Cơ cấu tiền lương\n Lương thường xuyên\n(Theo Phụ lục I)\n- Lương cấp bậc\n  - () Trong lương cấp bậc đã bao gồm Phụ cấp chức vụ, Phụ cấp đặc biệt, Phụ cấp chức ngành, Phụ cấp độc hại.\n  - Trợ cấp liên quan đời sống\n  - Trợ cấp nhà ở\n  - Trợ cấp đi lại\n  - Lunch Support\n  - Trợ cấp ăn trưa\n  - Trợ cấp khác (nếu có)\n Lương không thường xuyên\n- Phụ cấp làm thêm giờ ngày thường\n- Phụ cấp làm thêm giờ ngày nghỉ\n- Phụ cấp làm đêm',
#   'summary': 'Đoạn văn bản này chứa thông tin về cơ cấu tiền lương, bao gồm lương thường xuyên và lương không thường xuyên cùng các loại phụ cấp liên quan.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 2,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '# Điều 3: Lương thường xuyên\n(*) Thể hiện tại Phụ lục I, trong đó:\n+ Ngạch lương thể hiện vị trí, chức năng, nghiệp vụ của nhân viên.\n+ Bậc lương thể hiện thứ bậc được sắp xếp theo thứ tự ở mỗi ngạch lương.\n+ Mức lương thể hiện giá trị trọng mỗi bậc lương (từ tối thiểu đến tối đa).\n# Lương thưởng xuyên\n(*) Lương thưởng xuyên bao gồm 2 yếu tố dưới đây:  \nLương thưởng xuyên = Lương cấp bậc + Phụ cấp đời sống\n1- Công ty xây dựng Bảng lương thưởng xuyên trên cơ sở xem xét mức lương tối thiểu theo quy định của pháp luật và/h hoặc chỉ số giá tiêu dùng được ban hành bởi Chính phủ cũng như Báo cáo khảo sát tiền lương trên thị trường lao động Việt Nam (dữ liệu tham khảo hiện nay là Khảo sát lương 2023 dành cho khối sản xuất có vốn đầu tư Nhật Bản do tập đoàn Navigos công bố).\n2- Ít nhất 1 lần trong 5 năm, Bảng lương thưởng xuyên sẽ được chỉnh sửa nếu thấy kết quả khảo sát lương trên thị trường lao động có sự thay đổi đáng kể hoặc chỉ số giá tiêu dùng biến động từ 15% trở lên.\n3- Bảng Lương thưởng xuyên được phân thành 5 nhóm theo phạm vi công việc của từng nhân viên như sau:\n1) Nhóm 1 / Nhóm Quản lý (M): Cấp Trưởng Phòng, Trưởng Ban, Giám đốc nhà máy.  \n2) Nhóm 2 / Nhóm Chuyên viên (P): Tổ trưởng, Nhóm trưởng và những nhân viên có kỹ năng nghề nghiệp cao, được xét chọn bởi Nhóm Quản lý.  \n3) Nhóm 3 (E)/ Kỹ sư, chuyên gia, người có kinh nghiệm.  \n4) Nhóm 4 (G)/ Nhân viên nghiệp vụ: làm công việc hỗ trợ dịch vụ, hành chính tại các bộ phận.  \n5) Nhóm 5 (S)/ Công nhân kỹ thuật: làm việc trực tiếp tại xưởng sản xuất hoặc công trường.  \n## I. Lương cấp bậc bao gồm: Phụ cấp chức vụ, Phụ cấp đặc biệt, Phụ cấp kỹ năng nghề, Phụ cấp năng nhọc độc hại nguy hiểm, trong đó lưu ý:\na) Phụ cấp kỹ năng nghề  \nNgười lao động có chứng chỉ kỹ năng nghề nghiệp do JAVADA (Hiệp hội phát triển năng lực nghề nghiệp Nhật Bản) quy định hoặc tương đương sẽ được trả cấp kỹ năng nghề nghiệp hàng tháng. “Phụ cấp kỹ năng nghề” này được quy định tại Phụ lục II.\nb) Phụ cấp công việc năng nhọc, độc hại nguy hiểm  \nNgười lao động làm công việc năng nhọc, độc hại, nguy hiểm như liệt kê tại Phụ lục III: EVPC - Danh mục nghề, công việc năng nhọc, độc hại và đặc biệt năng nhọc, độc hại, sẽ được áp dụng Phụ cấp lao động năng nhọc là 500.000 đồng:\n- Nhóm Nấu luyện, nhóm Hoàn thiện và nhóm Khuôn đúc thuộc phòng Đức, ban Sản xuất & Vật liệu  \n- Nhóm Gò hàn rèn, phòng Gò hàn rèn, ban Sản xuất & Vật liệu  \n# Thông tin quản lý\n## II. Phụ cấp đời sống\n### 1. Phụ cấp nhà ở\nCông ty dự phòng chi trả Phụ cấp nhà ở 500,000 đồng cho nhân viên sống tại tỉnh Hải Dương và các tỉnh khác (trừ Hà Nội, Hồ Chí Minh và Đồng Nai) và 1,000,000 đồng cho nhân viên cư trú tại Thành phố Hà Nội, Thành phố Hồ Chí Minh và tỉnh Đồng Nai.\n### 2. Phụ cấp di lại\nCông ty hỗ trợ phụ cấp di lại cho toàn thể nhân viên 500,000đ.\n### 3. Phụ cấp hỗ trợ ăn trưa\nNhân viên làm việc tại Văn phòng đại diện Hà Nội, Chi nhánh Đồng Nai được hỗ trợ ăn trưa 800,000đ. Nhân viên làm việc tại Trụ sở chính và Nhà máy được cung cấp bữa trưa miễn phí tại công ty.\n### 4. Phụ cấp khác\n- Người lao động được hưởng bảo hiểm xã hội (đã nghỉ hưu nhưng vẫn tiếp tục làm việc tại công ty) được hưởng Trợ cấp Bảo hiểm xã hội theo quy định của Luật Lao động. Phụ cấp Bảo hiểm xã hội được tính dựa trên tổng số lương theo Lương cấp bậc.  \n- Đối với nhân viên được chỉ định thường xuyên di chuyển đến làm việc tại chi nhánh, nhà máy sẽ được hưởng Phụ cấp di lại (tối đa 2 triệu/tháng). Mức phụ cấp này do Tổng Giám đốc quyết định tùy theo từng trường hợp.',
#   'content': ' Điều 3: Lương thường xuyên\n() Thể hiện tại Phụ lục I, trong đó:\n+ Ngạch lương thể hiện vị trí, chức năng, nghiệp vụ của nhân viên.\n+ Bậc lương thể hiện thứ bậc được sắp xếp theo thứ tự ở mỗi ngạch lương.\n+ Mức lương thể hiện giá trị trọng mỗi bậc lương (từ tối thiểu đến tối đa).\n Lương thưởng xuyên\n() Lương thưởng xuyên bao gồm 2 yếu tố dưới đây:  \nLương thưởng xuyên = Lương cấp bậc + Phụ cấp đời sống\n1- Công ty xây dựng Bảng lương thưởng xuyên trên cơ sở xem xét mức lương tối thiểu theo quy định của pháp luật và/h hoặc chỉ số giá tiêu dùng được ban hành bởi Chính phủ cũng như Báo cáo khảo sát tiền lương trên thị trường lao động Việt Nam (dữ liệu tham khảo hiện nay là Khảo sát lương 2023 dành cho khối sản xuất có vốn đầu tư Nhật Bản do tập đoàn Navigos công bố).\n2- Ít nhất 1 lần trong 5 năm, Bảng lương thưởng xuyên sẽ được chỉnh sửa nếu thấy kết quả khảo sát lương trên thị trường lao động có sự thay đổi đáng kể hoặc chỉ số giá tiêu dùng biến động từ 15% trở lên.\n3- Bảng Lương thưởng xuyên được phân thành 5 nhóm theo phạm vi công việc của từng nhân viên như sau:\n1) Nhóm 1 / Nhóm Quản lý (M): Cấp Trưởng Phòng, Trưởng Ban, Giám đốc nhà máy.  \n2) Nhóm 2 / Nhóm Chuyên viên (P): Tổ trưởng, Nhóm trưởng và những nhân viên có kỹ năng nghề nghiệp cao, được xét chọn bởi Nhóm Quản lý.  \n3) Nhóm 3 (E)/ Kỹ sư, chuyên gia, người có kinh nghiệm.  \n4) Nhóm 4 (G)/ Nhân viên nghiệp vụ: làm công việc hỗ trợ dịch vụ, hành chính tại các bộ phận.  \n5) Nhóm 5 (S)/ Công nhân kỹ thuật: làm việc trực tiếp tại xưởng sản xuất hoặc công trường.  \n I. Lương cấp bậc bao gồm: Phụ cấp chức vụ, Phụ cấp đặc biệt, Phụ cấp kỹ năng nghề, Phụ cấp năng nhọc độc hại nguy hiểm, trong đó lưu ý:\na) Phụ cấp kỹ năng nghề  \nNgười lao động có chứng chỉ kỹ năng nghề nghiệp do JAVADA (Hiệp hội phát triển năng lực nghề nghiệp Nhật Bản) quy định hoặc tương đương sẽ được trả cấp kỹ năng nghề nghiệp hàng tháng. “Phụ cấp kỹ năng nghề” này được quy định tại Phụ lục II.\nb) Phụ cấp công việc năng nhọc, độc hại nguy hiểm  \nNgười lao động làm công việc năng nhọc, độc hại, nguy hiểm như liệt kê tại Phụ lục III: EVPC - Danh mục nghề, công việc năng nhọc, độc hại và đặc biệt năng nhọc, độc hại, sẽ được áp dụng Phụ cấp lao động năng nhọc là 500.000 đồng:\n- Nhóm Nấu luyện, nhóm Hoàn thiện và nhóm Khuôn đúc thuộc phòng Đức, ban Sản xuất & Vật liệu  \n- Nhóm Gò hàn rèn, phòng Gò hàn rèn, ban Sản xuất & Vật liệu  \n Thông tin quản lý\n II. Phụ cấp đời sống\n 1. Phụ cấp nhà ở\nCông ty dự phòng chi trả Phụ cấp nhà ở 500,000 đồng cho nhân viên sống tại tỉnh Hải Dương và các tỉnh khác (trừ Hà Nội, Hồ Chí Minh và Đồng Nai) và 1,000,000 đồng cho nhân viên cư trú tại Thành phố Hà Nội, Thành phố Hồ Chí Minh và tỉnh Đồng Nai.\n 2. Phụ cấp di lại\nCông ty hỗ trợ phụ cấp di lại cho toàn thể nhân viên 500,000đ.\n 3. Phụ cấp hỗ trợ ăn trưa\nNhân viên làm việc tại Văn phòng đại diện Hà Nội, Chi nhánh Đồng Nai được hỗ trợ ăn trưa 800,000đ. Nhân viên làm việc tại Trụ sở chính và Nhà máy được cung cấp bữa trưa miễn phí tại công ty.\n 4. Phụ cấp khác\n- Người lao động được hưởng bảo hiểm xã hội (đã nghỉ hưu nhưng vẫn tiếp tục làm việc tại công ty) được hưởng Trợ cấp Bảo hiểm xã hội theo quy định của Luật Lao động. Phụ cấp Bảo hiểm xã hội được tính dựa trên tổng số lương theo Lương cấp bậc.  \n- Đối với nhân viên được chỉ định thường xuyên di chuyển đến làm việc tại chi nhánh, nhà máy sẽ được hưởng Phụ cấp di lại (tối đa 2 triệu/tháng). Mức phụ cấp này do Tổng Giám đốc quyết định tùy theo từng trường hợp.',
#   'summary': 'Đoạn văn bản này chứa thông tin về cấu trúc và các yếu tố liên quan đến lương thưởng xuyên của nhân viên trong công ty.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 2,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '#### Điều 4. Kỳ tính lương\nKỳ tính lương được xác định như sau:  \n1. Lương thường xuyên: Từ ngày 1 đến cuối tháng hiện tại  \n2. Lương không thường xuyên: Từ ngày 1 đến cuối tháng hiện tại',
#   'content': ' Điều 4. Kỳ tính lương\nKỳ tính lương được xác định như sau:  \n1. Lương thường xuyên: Từ ngày 1 đến cuối tháng hiện tại  \n2. Lương không thường xuyên: Từ ngày 1 đến cuối tháng hiện tại',
#   'summary': 'Đoạn văn bản này chứa thông tin về kỳ tính lương trong một tổ chức.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 4,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '#### Điều 5. Phương thức trả lương\nCông ty trả lương bằng tiền mặt hoặc chuyển khoản vào tài khoản ngân hàng của người lao động.',
#   'content': ' Điều 5. Phương thức trả lương\nCông ty trả lương bằng tiền mặt hoặc chuyển khoản vào tài khoản ngân hàng của người lao động.',
#   'summary': 'Đoạn văn bản này chứa thông tin về phương thức trả lương của công ty.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 4,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '#### Điều 6. Ngày trả lương\nTiền lương phải được mô tả chi tiết vào trước ngày trả lương và công ty thực hiện chỉ trả cho người lao động vào ngày 10 của tháng tiếp theo. Người lao động có thể bị khấu trừ lương trong các trường hợp.\n# Confidential\n1) \na. Thuế thu nhập cá nhân  \nb. Bảo hiểm xã hội, bảo hiểm y tế, bảo hiểm thất nghiệp  \nc. Các khoản trừ trước  \nd. Bồi thường  \ne. Các chi phí khác do Công ty và Công đoàn thoả thuận.  \n2) Trường hợp ngày thanh toán lương là ngày nghỉ lễ thì việc trả lương được thực hiện vào ngày làm việc trước đó.  \n3) Tiền lương được ưu tiên thanh toán trước các chi phí khác.  \n4) Việc đóng Bảo hiểm xã hội được tính căn cứ vào tiền lương Cấp bậc (không tính phụ cấp liên quan đến đời sống).  \n5) Việc thay đổi ngày trả lương do trưởng hợp kháng phải thông báo cho người lao động trước 7 ngày. Công ty có trách nhiệm trả lãi cho người lao động theo quy định của ngân hàng nếu chậm trả lương từ 15 ngày trở lên.  \n6) Khấu trừ lương  \nTrường hợp vắng mặt (do nghỉ không lương, nghỉ hưởng chế độ Bảo hiểm xã hội, …), công ty sẽ khấu trừ vào lương của người lao động theo công thức sau:  \n$$ Khấu trừ 1 ngày vắng mặt = Lương thưởng xuyên $$  \n$$ = \\text{Số ngày làm việc tiêu chuẩn hàng tháng} (= 22*) $$',
#   'content': ' Điều 6. Ngày trả lương\nTiền lương phải được mô tả chi tiết vào trước ngày trả lương và công ty thực hiện chỉ trả cho người lao động vào ngày 10 của tháng tiếp theo. Người lao động có thể bị khấu trừ lương trong các trường hợp.\n Confidential\n1) \na. Thuế thu nhập cá nhân  \nb. Bảo hiểm xã hội, bảo hiểm y tế, bảo hiểm thất nghiệp  \nc. Các khoản trừ trước  \nd. Bồi thường  \ne. Các chi phí khác do Công ty và Công đoàn thoả thuận.  \n2) Trường hợp ngày thanh toán lương là ngày nghỉ lễ thì việc trả lương được thực hiện vào ngày làm việc trước đó.  \n3) Tiền lương được ưu tiên thanh toán trước các chi phí khác.  \n4) Việc đóng Bảo hiểm xã hội được tính căn cứ vào tiền lương Cấp bậc (không tính phụ cấp liên quan đến đời sống).  \n5) Việc thay đổi ngày trả lương do trưởng hợp kháng phải thông báo cho người lao động trước 7 ngày. Công ty có trách nhiệm trả lãi cho người lao động theo quy định của ngân hàng nếu chậm trả lương từ 15 ngày trở lên.  \n6) Khấu trừ lương  \nTrường hợp vắng mặt (do nghỉ không lương, nghỉ hưởng chế độ Bảo hiểm xã hội, …), công ty sẽ khấu trừ vào lương của người lao động theo công thức sau:  \n$$ Khấu trừ 1 ngày vắng mặt = Lương thưởng xuyên $$  \n$$ = text{Số ngày làm việc tiêu chuẩn hàng tháng} (= 22) $$',
#   'summary': 'Đoạn văn bản này chứa thông tin về quy định và quy trình liên quan đến việc trả lương cho người lao động.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 4,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '## Điều 7. Trả lương trong thời gian thử việc  \nTrong thời gian thử việc, tiền lương được tính theo công thức sau:  \n$$ Lương tháng trong thời gian thử việc = [\\text{Lương thưởng xuyên} * 85\\% ] $$  \n$$ = \\text{Ngày làm việc tiêu chuẩn hàng tháng (22 ngày)} $$',
#   'content': ' Điều 7. Trả lương trong thời gian thử việc  \nTrong thời gian thử việc, tiền lương được tính theo công thức sau:  \n$$ Lương tháng trong thời gian thử việc = [text{Lương thưởng xuyên}  85% ] $$  \n$$ = text{Ngày làm việc tiêu chuẩn hàng tháng (22 ngày)} $$',
#   'summary': 'Đoạn văn bản này chứa thông tin về cách tính lương trong thời gian thử việc.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 5,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '## Điều 8. Thanh toán đặc biệt  \nKhi xem xét yêu cầu thuộc các trường hợp sau đây, Công ty phải trả lương cho người lao động theo phần công việc hoa nhân và không phụ thuộc vào Điều 6 - Ngày trả lương:  \n1) Nhân viên/cán bộ chết.  \n2) Chấm dứt hợp đồng lao động.  \n3) Nhân viên/Cán bộ hoặc gia đình họ cần tiền để chi trả cho tai nạn, thương tích, bệnh tật hoặc thiên tai.  \n4) Nhân viên/Cán bộ hoặc gia đình họ cần tiền để chi trả cho đám cưới, sinh con, tang lễ.\n# 5) Các trường hợp sự chấp thuận của Công ty.',
#   'content': ' Điều 8. Thanh toán đặc biệt  \nKhi xem xét yêu cầu thuộc các trường hợp sau đây, Công ty phải trả lương cho người lao động theo phần công việc hoa nhân và không phụ thuộc vào Điều 6 - Ngày trả lương:  \n1) Nhân viên/cán bộ chết.  \n2) Chấm dứt hợp đồng lao động.  \n3) Nhân viên/Cán bộ hoặc gia đình họ cần tiền để chi trả cho tai nạn, thương tích, bệnh tật hoặc thiên tai.  \n4) Nhân viên/Cán bộ hoặc gia đình họ cần tiền để chi trả cho đám cưới, sinh con, tang lễ.\n 5) Các trường hợp sự chấp thuận của Công ty.',
#   'summary': 'Đoạn văn bản này quy định về các trường hợp thanh toán đặc biệt cho người lao động trong các tình huống cụ thể.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 5,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '#### Điều 9. Tạm ứng tiền lương\nTrong khi xem xét yêu cầu hoặc các trường hợp sau đây, Công ty sẽ tạm ứng trước cho người lao động. Tuy nhiên, nó phải đảm bảo tuân thủ các quy định khác.\n1) Nhân viên/Cán bộ hoặc gia đình họ cần tiền để chi trả cho những khó khăn phát sinh.\n2) Nhân viên/Cán bộ nghỉ để tham gia các hoạt động theo yêu cầu của Chính quyền.\n3) Các trường hợp có sự chấp thuận của Công ty.',
#   'content': ' Điều 9. Tạm ứng tiền lương\nTrong khi xem xét yêu cầu hoặc các trường hợp sau đây, Công ty sẽ tạm ứng trước cho người lao động. Tuy nhiên, nó phải đảm bảo tuân thủ các quy định khác.\n1) Nhân viên/Cán bộ hoặc gia đình họ cần tiền để chi trả cho những khó khăn phát sinh.\n2) Nhân viên/Cán bộ nghỉ để tham gia các hoạt động theo yêu cầu của Chính quyền.\n3) Các trường hợp có sự chấp thuận của Công ty.',
#   'summary': 'Đoạn văn bản này chứa thông tin về quy định tạm ứng tiền lương cho nhân viên trong các trường hợp cụ thể.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '#### Điều 10. Lương không thường xuyên\nPhụ cấp này được tính theo công thức sau:\nPhụ cấp làm thêm ngoài giờ (mỗi 1 giờ)  \n$$ \n= (Lương cấp bậc) * Hệ số phụ cấp * 1 \n$$  \n$$ \n= (Lương cấp bậc) * Hệ số phụ cấp * 1 \n$$  \n$$ \n= 22 (ngày) * 8 (giờ) \n$$  \n*1) Hệ số phụ cấp được tính như sau:\nNgày thường | Thứ 7, Chủ nhật & Ngày nghỉ lễ của Công ty | Ngày lễ  \n---|---|---  \n6:00AM - 22:00 | 1.5 | 2.0 | 3.0  \n22:00 - 6:00AM | 2.1 | 2.7 | 3.9  \n$$ \n= 1.5 + 0.3*2 + (0.2) \\times 1.5 \n$$  \n$$ \n= 2.0 + 0.3*2 + (0.2) \\times 2.0 \n$$  \n$$ \n= 3.0 + 0.3*2 + (0.2) \\times 3.0 \n$$  \n*2) Hệ số phụ cấp làm việc ca đêm  \n*3) Hệ số phụ cấp làm thêm giờ vào ban đêm  \nPhụ cấp làm việc ca đêm  \nNgười lao động làm việc ca đêm (từ 22h đến 6h) được hưởng thêm các khoản phụ cấp sau:  \nPhụ cấp làm việc ca ban đêm (mỗi 1 giờ)  \n$$ \n= (Lương cấp bậc) * 0.3 \n$$  \n$$ \n= (Lương cấp bậc) * 0.3 \n$$  \n$$ \n= 22 (ngày) * 8 (giờ) \n$$  \n(*) Làm thêm giờ chỉ áp dụng đối với các công việc trực tiếp tại nhà máy, văn phòng, công trường dự án. Thời gian tiếp khách hoặc di chuyển trên đường sẽ không được tính là làm thêm giờ.\n',
#   'content': ' Điều 10. Lương không thường xuyên\nPhụ cấp này được tính theo công thức sau:\nPhụ cấp làm thêm ngoài giờ (mỗi 1 giờ)  \n$$ \n= (Lương cấp bậc)  Hệ số phụ cấp  1 \n$$  \n$$ \n= (Lương cấp bậc)  Hệ số phụ cấp  1 \n$$  \n$$ \n= 22 (ngày)  8 (giờ) \n$$  \n1) Hệ số phụ cấp được tính như sau:\nNgày thường | Thứ 7, Chủ nhật & Ngày nghỉ lễ của Công ty | Ngày lễ  \n---|---|---  \n6:00AM - 22:00 | 1.5 | 2.0 | 3.0  \n22:00 - 6:00AM | 2.1 | 2.7 | 3.9  \n$$ \n= 1.5 + 0.32 + (0.2) times 1.5 \n$$  \n$$ \n= 2.0 + 0.32 + (0.2) times 2.0 \n$$  \n$$ \n= 3.0 + 0.32 + (0.2) times 3.0 \n$$  \n2) Hệ số phụ cấp làm việc ca đêm  \n3) Hệ số phụ cấp làm thêm giờ vào ban đêm  \nPhụ cấp làm việc ca đêm  \nNgười lao động làm việc ca đêm (từ 22h đến 6h) được hưởng thêm các khoản phụ cấp sau:  \nPhụ cấp làm việc ca ban đêm (mỗi 1 giờ)  \n$$ \n= (Lương cấp bậc)  0.3 \n$$  \n$$ \n= (Lương cấp bậc)  0.3 \n$$  \n$$ \n= 22 (ngày)  8 (giờ) \n$$  \n() Làm thêm giờ chỉ áp dụng đối với các công việc trực tiếp tại nhà máy, văn phòng, công trường dự án. Thời gian tiếp khách hoặc di chuyển trên đường sẽ không được tính là làm thêm giờ.\n',
#   'summary': 'Đoạn văn bản này chứa thông tin về cách tính lương và phụ cấp cho người lao động làm thêm giờ và làm việc ca đêm.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '# Điều 11. Lương ngừng việc\nCăn cứ Điều 99 Bộ luật Lao động 2019, trường hợp tạm ngừng việc thì tiền lương ngừng việc được trả như sau:\n1) Nếu do lỗi từ phía Công ty, người lao động được thanh toán lương theo Bảng lương.\n2) Nếu do lỗi từ phía người lao động thì người lao động đươc không được trả lương.\n3) Trường hợp vì sự cố diện, nước không phải do lỗi của Công ty hoặc do thiên tai, hoả hoạn, dịch bệnh, dịch hoạ, di dời theo yêu cầu của cơ quan có thẩm quyền hoặc vì do kinh tế, hai bên sẽ thoả thuận mức lương như sau:\na) Nếu thời gian ngừng việc không quá 14 ngày làm việc; tùy trường hợp công ty sẽ bố trí làm việc trả lương vào ngày khác hoặc bố trí nghỉ phép hằng năm hoặc công ty trả 75% lương theo Bảng lương.\nb) Nếu ngừng việc quá 14 ngày làm việc thì mức lương do hai bên thoả thuận (nhưng không thấp hơn mức lương tối thiểu vùng I hiện hành của Chính phủ).',
#   'content': ' Điều 11. Lương ngừng việc\nCăn cứ Điều 99 Bộ luật Lao động 2019, trường hợp tạm ngừng việc thì tiền lương ngừng việc được trả như sau:\n1) Nếu do lỗi từ phía Công ty, người lao động được thanh toán lương theo Bảng lương.\n2) Nếu do lỗi từ phía người lao động thì người lao động đươc không được trả lương.\n3) Trường hợp vì sự cố diện, nước không phải do lỗi của Công ty hoặc do thiên tai, hoả hoạn, dịch bệnh, dịch hoạ, di dời theo yêu cầu của cơ quan có thẩm quyền hoặc vì do kinh tế, hai bên sẽ thoả thuận mức lương như sau:\na) Nếu thời gian ngừng việc không quá 14 ngày làm việc; tùy trường hợp công ty sẽ bố trí làm việc trả lương vào ngày khác hoặc bố trí nghỉ phép hằng năm hoặc công ty trả 75% lương theo Bảng lương.\nb) Nếu ngừng việc quá 14 ngày làm việc thì mức lương do hai bên thoả thuận (nhưng không thấp hơn mức lương tối thiểu vùng I hiện hành của Chính phủ).',
#   'summary': 'Đoạn văn bản này chứa thông tin về quy định trả lương trong trường hợp tạm ngừng việc theo Bộ luật Lao động 2019.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 7,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '# Điều 12. Đánh giá, xác định tiền lương và quy chế tăng/ giảm lương\n1) Định kỳ hàng tháng/ quý hoặc năm, Công ty có thể xem xét và xác định mức lương của nhân viên dựa trên khả năng, trình độ, điều kiện làm việc, vai trò, kết quả đánh giá hiệu quả công việc, sự tuân thủ nội quy quy định, tiến trình chuyên cần. Các trường hợp đặc biệt Công ty có thể thay đổi mức lương khi thấy cần thiết căn cứ vào hiệu quả công việc thực tế của từng trường hợp cụ thể.\n2) Tăng tiền lương và tiêu chuẩn xác định mức lương được xác định theo trường hợp cụ thể căn cứ theo kết quả đánh giá hiệu quả công việc của nhân viên và phân loại đánh giá theo phương pháp đánh giá như sau:\nXếp loại đánh giá | Loại | Ghi chú  \n--- | --- | ---  \nXuất sắc | A | Thể hiện năng lực xuất sắc  \nTốt | B+/B | Thể hiện năng lực cao hơn mức yêu cầu  \nTrung bình | C | Thể hiện năng lực đạt mức yêu cầu  \nKém | D | Thể hiện năng lực thấp hơn mức yêu cầu  \n',
#   'content': ' Điều 12. Đánh giá, xác định tiền lương và quy chế tăng/ giảm lương\n1) Định kỳ hàng tháng/ quý hoặc năm, Công ty có thể xem xét và xác định mức lương của nhân viên dựa trên khả năng, trình độ, điều kiện làm việc, vai trò, kết quả đánh giá hiệu quả công việc, sự tuân thủ nội quy quy định, tiến trình chuyên cần. Các trường hợp đặc biệt Công ty có thể thay đổi mức lương khi thấy cần thiết căn cứ vào hiệu quả công việc thực tế của từng trường hợp cụ thể.\n2) Tăng tiền lương và tiêu chuẩn xác định mức lương được xác định theo trường hợp cụ thể căn cứ theo kết quả đánh giá hiệu quả công việc của nhân viên và phân loại đánh giá theo phương pháp đánh giá như sau:\nXếp loại đánh giá | Loại | Ghi chú  \n--- | --- | ---  \nXuất sắc | A | Thể hiện năng lực xuất sắc  \nTốt | B+/B | Thể hiện năng lực cao hơn mức yêu cầu  \nTrung bình | C | Thể hiện năng lực đạt mức yêu cầu  \nKém | D | Thể hiện năng lực thấp hơn mức yêu cầu  \n',
#   'summary': 'Đoạn văn bản này chứa thông tin về quy trình đánh giá và xác định mức lương của nhân viên trong công ty.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 7,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '# Điều 13. Điều kiện chuyển đổi Ngạch lương/Bậc lương\n1- Việc chuyển đổi Ngạch lương chỉ áp dụng khi người lao động được giao một công việc hoặc chức vụ mới.\n2- Việc chuyển đổi bậc lương trong mỗi ngạch lương sẽ áp dụng như sau:\n## Bậc lương chuyển đổi\n### Đối tượng được xét chuyển đổi\n| Ngạch P    | Nhóm 2 Tổ trưởng, Nhân viên, Chuyên viên                           | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B* > B > C > D |\n|------------|---------------------------------------------------------------------|---------------------------------------------|----------|--------------------|\n| Ngạch E    | Nhóm 3 Kỹ sư, cử nhân người có KN                                   | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B* > B > C > D |\n| Ngạch G    | Nhóm 3 Nhân viên nghiệp vụ                                         | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B* > B > C > D |\n| Ngạch S    | Nhóm 4 Công nhân kỹ thuật                                          | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B* > B > C > D |\n| Ngạch M    | Nhóm 1/Quản lý                                                     | Tổng Giám Đốc trực tiếp đánh giá các Trưởng Ban thông qua phòng vận trực tiếp |          |                    |\n# Quy chế xét tăng/giảm lương:\n- Người lao động được đánh giá loại A sẽ được tăng 100% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.\n- Người lao động được đánh giá loại B sẽ được tăng 80% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.\n- Người lao động được đánh giá loại C sẽ được tăng 70% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.\n- Người lao động được đánh giá loại D sẽ chỉ được 50% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.\n- (*) Trường hợp đặc biệt khi NLD bị đánh giá loại D 3 năm liên tiếp thì xem xét chấm đứt HĐLĐ.\n- Trường hợp đặc biệt khác cần đưa ra điều kiện tăng bậc lương, tùy nhiên cần được cán bộ nhân sự chấp thuận trước ủy Ban Giám Đốc.',
#   'content': ' Điều 13. Điều kiện chuyển đổi Ngạch lương/Bậc lương\n1- Việc chuyển đổi Ngạch lương chỉ áp dụng khi người lao động được giao một công việc hoặc chức vụ mới.\n2- Việc chuyển đổi bậc lương trong mỗi ngạch lương sẽ áp dụng như sau:\n Bậc lương chuyển đổi\n Đối tượng được xét chuyển đổi\n| Ngạch P    | Nhóm 2 Tổ trưởng, Nhân viên, Chuyên viên                           | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B > B > C > D |\n|------------|---------------------------------------------------------------------|---------------------------------------------|----------|--------------------|\n| Ngạch E    | Nhóm 3 Kỹ sư, cử nhân người có KN                                   | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B > B > C > D |\n| Ngạch G    | Nhóm 3 Nhân viên nghiệp vụ                                         | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B > B > C > D |\n| Ngạch S    | Nhóm 4 Công nhân kỹ thuật                                          | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng | A > B > B > C > D |\n| Ngạch M    | Nhóm 1/Quản lý                                                     | Tổng Giám Đốc trực tiếp đánh giá các Trưởng Ban thông qua phòng vận trực tiếp |          |                    |\n Quy chế xét tăng/giảm lương:\n- Người lao động được đánh giá loại A sẽ được tăng 100% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.\n- Người lao động được đánh giá loại B sẽ được tăng 80% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.\n- Người lao động được đánh giá loại C sẽ được tăng 70% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.\n- Người lao động được đánh giá loại D sẽ chỉ được 50% giá trị của khoảng cách giữa mức lương hiện tại với mức lương bậc cao hơn kế tiếp.\n- () Trường hợp đặc biệt khi NLD bị đánh giá loại D 3 năm liên tiếp thì xem xét chấm đứt HĐLĐ.\n- Trường hợp đặc biệt khác cần đưa ra điều kiện tăng bậc lương, tùy nhiên cần được cán bộ nhân sự chấp thuận trước ủy Ban Giám Đốc.',
#   'summary': 'Đoạn văn bản này chứa thông tin về điều kiện và quy trình chuyển đổi ngạch lương và bậc lương cho người lao động.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 8,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '#### Điều 14. Tiền lương nghỉ phép hàng năm và ngày nghỉ đặc biệt được hưởng nguyên lương\n- Công ty sẽ thanh toán những phép tôn đối với người lao động do thời viện hoặc mất việc làm.\n  + Ngày nghỉ phép hàng năm chưa dùng sẽ được tính theo công thức sau:\n$$\n\\text{Lương cấp bậc} = \\frac{\\text{Số ngày làm việc tiêu chuẩn hàng tháng (= 22)}}{\\text{Thanh toán một ngày phép tôn}}\n$$',
#   'content': ' Điều 14. Tiền lương nghỉ phép hàng năm và ngày nghỉ đặc biệt được hưởng nguyên lương\n- Công ty sẽ thanh toán những phép tôn đối với người lao động do thời viện hoặc mất việc làm.\n  + Ngày nghỉ phép hàng năm chưa dùng sẽ được tính theo công thức sau:\n$$\ntext{Lương cấp bậc} = frac{text{Số ngày làm việc tiêu chuẩn hàng tháng (= 22)}}{text{Thanh toán một ngày phép tôn}}\n$$',
#   'summary': 'Đoạn văn bản này chứa thông tin về quy định thanh toán lương cho ngày nghỉ phép hàng năm và các ngày nghỉ đặc biệt của người lao động.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 9,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '#### Điều 15. Trả lương cho gia đình người lao động qua đời\nGiải quyết việc thanh toán tiền lương cho thân nhân người lao động qua đời được thực hiện theo quy định của pháp luật Việt Nam.',
#   'content': ' Điều 15. Trả lương cho gia đình người lao động qua đời\nGiải quyết việc thanh toán tiền lương cho thân nhân người lao động qua đời được thực hiện theo quy định của pháp luật Việt Nam.',
#   'summary': 'Đoạn văn bản này chứa thông tin về quy định thanh toán tiền lương cho gia đình người lao động qua đời theo pháp luật Việt Nam.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 9,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '#### Điều 16. Tiền thưởng cuối năm\n1) Công ty thực hiện việc thanh toán thưởng mỗi năm một lần khi hoạt động kinh doanh có lãi.\n2) Tiền thưởng được căn cứ vào tiền lương Cấp bậc và Kết quả đóng góp của người lao động trong năm đó dựa vào Bảng đánh giá cuối năm (MBO hoặc trung đường).\n3) Nếu hoạt động kinh doanh của Công ty không có lãi thì tiền thưởng sẽ không có hoặc việc thanh toán Tiền thưởng sẽ bị hoãn.\n4) Người lao động nghỉ việc trước ngày 31 tháng 12 hàng năm không được thưởng. Tuy nhiên nếu Người lao động nghỉ hưu vào thời điểm trước 31/12 hàng năm thì sẽ được xem thưởng dựa trên số tháng còn làm việc tại công ty trong năm cuối cùng đó. Việc trả thưởng sẽ tiến hành vào thời điểm cuối năm mà NLD đã nghỉ hưu sẽ chịu thuế TNCN theo luật định tại thời điểm nhận thưởng.\n5) Trường hợp thưởng đặc biệt khác cần được quy định của Tổng Giám đốc.\n6) Tiền thưởng phải được tính như sau:\nTổng tiền thưởng = Tiền thưởng x Tỷ lệ làm việc trong năm\n',
#   'content': ' Điều 16. Tiền thưởng cuối năm\n1) Công ty thực hiện việc thanh toán thưởng mỗi năm một lần khi hoạt động kinh doanh có lãi.\n2) Tiền thưởng được căn cứ vào tiền lương Cấp bậc và Kết quả đóng góp của người lao động trong năm đó dựa vào Bảng đánh giá cuối năm (MBO hoặc trung đường).\n3) Nếu hoạt động kinh doanh của Công ty không có lãi thì tiền thưởng sẽ không có hoặc việc thanh toán Tiền thưởng sẽ bị hoãn.\n4) Người lao động nghỉ việc trước ngày 31 tháng 12 hàng năm không được thưởng. Tuy nhiên nếu Người lao động nghỉ hưu vào thời điểm trước 31/12 hàng năm thì sẽ được xem thưởng dựa trên số tháng còn làm việc tại công ty trong năm cuối cùng đó. Việc trả thưởng sẽ tiến hành vào thời điểm cuối năm mà NLD đã nghỉ hưu sẽ chịu thuế TNCN theo luật định tại thời điểm nhận thưởng.\n5) Trường hợp thưởng đặc biệt khác cần được quy định của Tổng Giám đốc.\n6) Tiền thưởng phải được tính như sau:\nTổng tiền thưởng = Tiền thưởng x Tỷ lệ làm việc trong năm\n',
#   'summary': 'Đoạn văn bản này chứa thông tin về quy định và điều kiện thanh toán tiền thưởng cuối năm cho người lao động trong công ty.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 9,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '#### Điều 17. Tiền thưởng thâm niên\nCông ty thực hiện việc thưởng thâm niên vào cuối mỗi năm dựa theo các mốc sau:\n| Number of years working at EVPC | Bonus amount (VND) |\n|----------------------------------|---------------------|\n| 5 years                          | 1.500.000           |\n| 10 years                         | 3.000.000           |\n| 15 years                         | 4.500.000           |\n| 20 years                         | 6.000.000           |\n| 25 years                         | 7.500.000           |\n| 30 years                         | 9.000.000           |\n| 35 years                         | 10.500.000          |\n| 40 years                         | 12.000.000          |\n$$ \\text{Tiền thưởng} = \\text{Ngày vắng mặt trong năm} \\times \\left(100 - \\frac{\\text{Ngày vắng mặt trong năm}}{22 \\times 12}\\right) $$\n',
#   'content': ' Điều 17. Tiền thưởng thâm niên\nCông ty thực hiện việc thưởng thâm niên vào cuối mỗi năm dựa theo các mốc sau:\n| Number of years working at EVPC | Bonus amount (VND) |\n|----------------------------------|---------------------|\n| 5 years                          | 1.500.000           |\n| 10 years                         | 3.000.000           |\n| 15 years                         | 4.500.000           |\n| 20 years                         | 6.000.000           |\n| 25 years                         | 7.500.000           |\n| 30 years                         | 9.000.000           |\n| 35 years                         | 10.500.000          |\n| 40 years                         | 12.000.000          |\n$$ text{Tiền thưởng} = text{Ngày vắng mặt trong năm} times left(100 - frac{text{Ngày vắng mặt trong năm}}{22 times 12}right) $$\n',
#   'summary': 'Đoạn văn bản này chứa thông tin về chính sách thưởng thâm niên của công ty và cách tính tiền thưởng dựa trên số năm làm việc.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 10,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '| Khấu trừ 1 ngày vắng mặt | = | Lương thường xuyên  | *  | (1 - Số ngày làm việc tiêu chuẩn hàng tháng (= 22*)) |\n\n',
#   'content': '| Khấu trừ 1 ngày vắng mặt | = | Lương thường xuyên  | *  | (1 - Số ngày làm việc tiêu chuẩn hàng tháng (= 22*)) |\n\n',
#   'summary': 'Đoạn văn bản này chứa thông tin về cách tính khấu trừ lương cho ngày vắng mặt trong công việc.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 5,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '| Lương tháng trong thời gian thử việc | = | [Lương thường xuyên * 85%] | * | (1 - Số ngày làm việc tiêu chuẩn hàng tháng (22 ngày) * \nSố ngày làm việc trong tháng)  |',
#   'content': '| Lương tháng trong thời gian thử việc | = | [Lương thường xuyên * 85%] | * | (1 - Số ngày làm việc tiêu chuẩn hàng tháng (22 ngày) * \nSố ngày làm việc trong tháng)  |',
#   'summary': 'Đoạn văn bản này chứa thông tin về cách tính lương tháng trong thời gian thử việc.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 5,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '|                   | Ngày thường | Thứ 7, Chủ nhật & Ngày nghỉ Lễ của Công ty | Ngày lễ  |\n|-------------------|--------------|--------------------------------------------|----------|\n| 6:00AM - 22:00    | 1.5          | 2.0                                        | 3.0      |\n| 22:00 - 6:00AM    | 2.1 = 1.5 + 0.3**3 + (0.2**3 x 1.5) | 2.7 = 2.0 + 0.3**3 + (0.2**3 x 2.0)          | 3.9 = 3.0 + 0.3**3 + (0.2**3 x 3.0) |',
#   'content': '|                   | Ngày thường | Thứ 7, Chủ nhật & Ngày nghỉ Lễ của Công ty | Ngày lễ  |\n|-------------------|--------------|--------------------------------------------|----------|\n| 6:00AM - 22:00    | 1.5          | 2.0                                        | 3.0      |\n| 22:00 - 6:00AM    | 2.1 = 1.5 + 0.3**3 + (0.2**3 x 1.5) | 2.7 = 2.0 + 0.3**3 + (0.2**3 x 2.0)          | 3.9 = 3.0 + 0.3**3 + (0.2**3 x 3.0) |',
#   'summary': 'Đoạn văn bản này chứa thông tin về tỷ lệ lương theo giờ làm việc trong các ngày khác nhau.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '| Xếp loại đánh giá | Loại | Ghi chú                          |\n|-------------------|------|-----------------------------------|\n| Xuất sắc          | A    | Thể hiện năng lực xuất sắc       |\n| Tốt               | B+/B | Thể hiện năng lực cao hơn mức yêu cầu |\n| Trung bình        | C    | Thể hiện năng lực đạt mức yêu cầu |\n| Kém               | D    | Thể hiện năng lực thấp hơn mức yêu cầu |',
#   'content': '| Xếp loại đánh giá | Loại | Ghi chú                          |\n|-------------------|------|-----------------------------------|\n| Xuất sắc          | A    | Thể hiện năng lực xuất sắc       |\n| Tốt               | B+/B | Thể hiện năng lực cao hơn mức yêu cầu |\n| Trung bình        | C    | Thể hiện năng lực đạt mức yêu cầu |\n| Kém               | D    | Thể hiện năng lực thấp hơn mức yêu cầu |',
#   'summary': 'Đoạn văn bản này chứa thông tin về hệ thống xếp loại đánh giá năng lực.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 7,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '| Bậc lương chuyển đổi | Đối tượng được xét chuyển đổi                                                           | Tiêu chuẩn được xét chuyển đổi                                                                 |\n|---------------------|-------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------|\n|                     |                                                                                     | Người đánh giá                          | Kinh nghiệm làm việc liên quan đến bậc lương được chuyển đổi | Xếp loại để được chuyển bậc                       |\n| Ngạch P             | Nhóm 2 Tổ Trưởng, Nhóm Trưởng, Chuyên viên                                          | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch E             | Nhóm 3 Kỹ sư, cử nhân người có KH                                                   | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch G             | Nhóm 3 Nhân viên nghiệp vụ                                                          | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch S             | Nhóm 4 Công nhân kỹ thuật                                                           | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch M             | Nhóm 1/ Quản lý                                                                     | Tổng Giám Đốc trực tiếp đánh giá cùng các Trưởng Ban thông qua phòng vấn trực tiếp |                                                    |        |',
#   'content': '| Bậc lương chuyển đổi | Đối tượng được xét chuyển đổi                                                           | Tiêu chuẩn được xét chuyển đổi                                                                 |\n|---------------------|-------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------|\n|                     |                                                                                     | Người đánh giá                          | Kinh nghiệm làm việc liên quan đến bậc lương được chuyển đổi | Xếp loại để được chuyển bậc                       |\n| Ngạch P             | Nhóm 2 Tổ Trưởng, Nhóm Trưởng, Chuyên viên                                          | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch E             | Nhóm 3 Kỹ sư, cử nhân người có KH                                                   | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch G             | Nhóm 3 Nhân viên nghiệp vụ                                                          | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch S             | Nhóm 4 Công nhân kỹ thuật                                                           | TL> GL> SM > GM trực tiếp và Ban Nhân Sự | 12 tháng                                                    | A > B* > B > C > D                                |\n| Ngạch M             | Nhóm 1/ Quản lý                                                                     | Tổng Giám Đốc trực tiếp đánh giá cùng các Trưởng Ban thông qua phòng vấn trực tiếp |                                                    |        |',
#   'summary': 'Đoạn văn bản này chứa thông tin về tiêu chuẩn và quy trình xét chuyển đổi bậc lương cho các nhóm nhân viên trong tổ chức.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 8,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': 'Thanh toán một ngày phép tồn = Lương cấp bậc / Số ngày làm việc tiêu chuẩn hàng tháng (= 22)',
#   'content': 'Thanh toán một ngày phép tồn = Lương cấp bậc / Số ngày làm việc tiêu chuẩn hàng tháng (= 22)',
#   'summary': 'Đoạn văn bản này chứa thông tin về cách tính toán thanh toán cho một ngày phép tồn.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 9,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ':\n\nNumber of years working at EVPC | Bonus amount (VND)\n--------------------------------|--------------------\n5 years                         | 1.500.000\n10 years                        | 3.000.000\n15 years                        | 4.500.000\n20 years                        | 6.000.000\n25 years                        | 7.500.000\n30 years                        | 9.000.000\n35 năm                          | 10.500.000\n40 năm                          | 12.000.000',
#   'content': ':\n\nNumber of years working at EVPC | Bonus amount (VND)\n--------------------------------|--------------------\n5 years                         | 1.500.000\n10 years                        | 3.000.000\n15 years                        | 4.500.000\n20 years                        | 6.000.000\n25 years                        | 7.500.000\n30 years                        | 9.000.000\n35 năm                          | 10.500.000\n40 năm                          | 12.000.000',
#   'summary': 'Đoạn văn bản này trình bày mối quan hệ giữa số năm làm việc tại EVPC và số tiền thưởng tương ứng.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 10,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' Khấu trừ 1 ngày vắng mặt = Lương thưởng xuyên ',
#   'content': 'Khấu trừ 1 ngày vắng mặt = Lương thưởng xuyên',
#   'summary': 'Đoạn văn bản này chứa thông tin về chính sách khấu trừ lương liên quan đến ngày vắng mặt.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 5,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' = \\\\text{Số ngày làm việc tiêu chuẩn hàng tháng} (= 22*) ',
#   'content': '=  Số ngày làm việc tiêu chuẩn hàng tháng (= 22*)',
#   'summary': 'Đoạn văn bản này chứa thông tin về số ngày làm việc tiêu chuẩn trong một tháng.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 5,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' Lương tháng trong thời gian thử việc = [\\\\text{Lương thưởng xuyên} * 85\\\\% ] ',
#   'content': 'Lương tháng trong thời gian thử việc = [ Lương thưởng xuyên * 85 % ]',
#   'summary': 'Đoạn văn bản này chứa thông tin về cách tính lương tháng trong thời gian thử việc.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 5,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' = \\\\text{Ngày làm việc tiêu chuẩn hàng tháng (22 ngày)} ',
#   'content': '=  Ngày làm việc tiêu chuẩn hàng tháng (22 ngày)',
#   'summary': 'Đoạn văn bản này chứa thông tin về số ngày làm việc tiêu chuẩn trong một tháng.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 5,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' \\n= (Lương cấp bậc) * Hệ số phụ cấp * 1 \\n',
#   'content': 'n= (Lương cấp bậc) * Hệ số phụ cấp * 1  n',
#   'summary': 'Đoạn văn bản này chứa thông tin về cách tính lương dựa trên cấp bậc và hệ số phụ cấp.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' \\n= (Lương cấp bậc) * Hệ số phụ cấp * 1 \\n',
#   'content': 'n= (Lương cấp bậc) * Hệ số phụ cấp * 1  n',
#   'summary': 'Đoạn văn bản này chứa thông tin về cách tính lương dựa trên cấp bậc và hệ số phụ cấp.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' \\n= 22 (ngày) * 8 (giờ) \\n',
#   'content': 'n= 22 (ngày) * 8 (giờ)  n',
#   'summary': 'Đoạn văn bản này chứa thông tin về ngày và thời gian.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' \\n= 1.5 + 0.3*2 + (0.2) \\\\times 1.5 \\n',
#   'content': 'n= 1.5 + 0.3*2 + (0.2)  * 1.5  n',
#   'summary': 'Đoạn văn bản này chứa thông tin về một biểu thức toán học.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' \\n= 2.0 + 0.3*2 + (0.2) \\\\times 2.0 \\n',
#   'content': 'n= 2.0 + 0.3*2 + (0.2)  * 2.0  n',
#   'summary': 'Đoạn văn bản này chứa thông tin về một biểu thức toán học.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' \\n= 3.0 + 0.3*2 + (0.2) \\\\times 3.0 \\n',
#   'content': 'n= 3.0 + 0.3*2 + (0.2)  * 3.0  n',
#   'summary': 'Đoạn văn bản này chứa thông tin về một biểu thức toán học.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' \\n= (Lương cấp bậc) * 0.3 \\n',
#   'content': 'n= (Lương cấp bậc) * 0.3  n',
#   'summary': 'Đoạn văn bản này chứa thông tin về công thức tính toán lương dựa trên cấp bậc.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' \\n= (Lương cấp bậc) * 0.3 \\n',
#   'content': 'n= (Lương cấp bậc) * 0.3  n',
#   'summary': 'Đoạn văn bản này chứa thông tin về công thức tính toán lương dựa trên cấp bậc.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' \\n= 22 (ngày) * 8 (giờ) \\n',
#   'content': 'n= 22 (ngày) * 8 (giờ)  n',
#   'summary': 'Đoạn văn bản này chứa thông tin về ngày và thời gian.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 6,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': '\\n\\\\text{Lương cấp bậc} = \\\\frac{\\\\text{Số ngày làm việc tiêu chuẩn hàng tháng (= 22)}}{\\\\text{Thanh toán một ngày phép tôn}}\\n',
#   'content': 'n Lương cấp bậc =  ( Số ngày làm việc tiêu chuẩn hàng tháng (= 22))/( Thanh toán một ngày phép tôn) n',
#   'summary': 'Đoạn văn bản này chứa thông tin về cách tính lương cấp bậc dựa trên số ngày làm việc và thanh toán cho ngày phép.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 9,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '},
#  {'raw_text': ' \\\\text{Tiền thưởng} = \\\\text{Ngày vắng mặt trong năm} \\\\times \\\\left(100 - \\\\frac{\\\\text{Ngày vắng mặt trong năm}}{22 \\\\times 12}\\\\right) ',
#   'content': 'Tiền thưởng =  Ngày vắng mặt trong năm  *  (100 -  ( Ngày vắng mặt trong năm)/(22  * 12) )',
#   'summary': 'Đoạn văn bản này chứa thông tin về cách tính toán tiền thưởng dựa trên số ngày vắng mặt trong năm.',
#   'src': 'thuvienphapluat/law_2. Tai lieu Khach hang cung cap_5. Salary Regulation 2024 (V) (1).pdf',
#   'chapter': '',
#   'page': 10,
#   'reference': 'QUY ĐỊNH VỀ TIỀN LƯƠNG – TIỀN THƯỞNG '}]
